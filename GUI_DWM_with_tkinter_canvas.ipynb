# %%
import tkinter as tk
from tkinter import Canvas, messagebox
import pyscreenshot as ImageGrab
import time
import os
from PIL import Image, ImageTk

window = tk.Tk()
window.title("Project")
window.resizable(True, True)

header = tk.Button(window, width=80, height=4, bg="pink", text="Handwritten Single Digit Recognition", font=("Arial", 14))
header.place(x=5, y=0)

canvas1 = Canvas(window, width=500, height=250, bg='ivory')
canvas1.place(x=5, y=120)

l1 = tk.Label(canvas1, text="Digit", font=('Algerian', 20))
l1.place(x=5, y=0)

t1 = tk.Entry(canvas1, width=20, border=5)
t1.place(x=150, y=5)

def screen_capture():
    os.startfile("C:/ProgramData/Microsoft/Windows/Start Menu/Programs/Accessories/Paint")
    s1 = t1.get()
    os.chdir("E:/DS and ML/Untitled Folder/Untitled Folder/captured_images")
    os.mkdir(s1)
    os.chdir("E:/DS and ML/Untitled Folder/Untitled Folder/")
    
    images_folder = "captured_images/" + s1 + "/"
    time.sleep(15)
    for i in range(0, 5):
        time.sleep(8)
        im = ImageGrab.grab(bbox=(60, 170, 400, 550))  # x1,y1,x2,y2
        print("saved......", i)
        im.save(images_folder + str(i) + '.png')
        print("clear screen now and redraw now........")
    messagebox.showinfo("Result", "Capturing screen is completed!!")

b1 = tk.Button(canvas1, text="1. Open paint and capture the screen", font=('Algerian', 15), bg="orange", fg="black", command=screen_capture)
b1.place(x=5, y=50)

def generate_dataset():
    import cv2
    import csv
    import glob

    header = ["label"]
    for i in range(0, 784):
        header.append("pixel" + str(i))
    with open('dataset.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow(header)

    for label in range(10):
        dirList = glob.glob("captured_images/" + str(label) + "/*.png")

        for img_path in dirList:
            im = cv2.imread(img_path)
            im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            im_gray = cv2.GaussianBlur(im_gray, (15, 15), 0)
            roi = cv2.resize(im_gray, (28, 28), interpolation=cv2.INTER_AREA)

            data = []
            data.append(label)
            rows, cols = roi.shape

            for i in range(rows):
                for j in range(cols):
                    k = roi[i, j]
                    if k > 100:
                        k = 1
                    else:
                        k = 0
                    data.append(k)
            with open('dataset.csv', 'a') as f:
                writer = csv.writer(f)
                writer.writerow(data)
    messagebox.showinfo("Result", "Generating dataset is completed!!")

b2 = tk.Button(canvas1, text="2. Generate dataset", font=('Algerian', 15), bg="pink", fg="blue", command=generate_dataset)
b2.place(x=5, y=100)

def train_save_accuracy():
    import pandas as pd
    from sklearn.utils import shuffle
    from sklearn.model_selection import train_test_split
    from sklearn.svm import SVC
    import joblib
    from sklearn import metrics

    data = pd.read_csv('dataset.csv')
    data = shuffle(data)
    X = data.drop(["label"], axis=1)
    Y = data["label"]

    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.2)

    classifier = SVC(kernel="linear", random_state=6)
    classifier.fit(train_x, train_y)
    joblib.dump(classifier, "model/digit_recognizer")

    prediction = classifier.predict(test_x)
    acc = metrics.accuracy_score(prediction, test_y)
    messagebox.showinfo("Result", f"Your accuracy is {acc}")

b3 = tk.Button(canvas1, text="3. Train the model and calculate accuracy", font=('Algerian', 15), bg="green", fg="white", command=train_save_accuracy)
b3.place(x=5, y=150)

def prediction():
    import joblib
    import cv2
    import numpy as np

    model = joblib.load("model/digit_recognizer")

    img = ImageGrab.grab(bbox=(400, 550, 930, 1080))
    img.save("paint.png")

    im = cv2.imread("paint.png")
    load = Image.open("paint.png")
    load = load.resize((280, 280))
    photo = ImageTk.PhotoImage(load)

    img_label = tk.Label(canvas3, image=photo, width=300, height=200)
    img_label.image = photo  # Keep reference to avoid garbage collection
    img_label.place(x=0, y=0)

    im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    im_gray = cv2.GaussianBlur(im_gray, (15, 15), 0)

    ret, im_th = cv2.threshold(im_gray, 100, 255, cv2.THRESH_BINARY)
    roi = cv2.resize(im_th, (28, 28), interpolation=cv2.INTER_AREA)

    rows, cols = roi.shape

    X = []
    for i in range(rows):
        for j in range(cols):
            k = roi[i, j]
            if k > 100:
                k = 1
            else:
                k = 0
            X.append(k)

    predictions = model.predict([X])

    a1 = tk.Label(canvas3, text="Prediction= ", font=("Algerian", 20))
    a1.place(x=5, y=350)

    b1 = tk.Label(canvas3, text=predictions[0], font=("Algerian", 20))
    b1.place(x=200, y=350)

b4 = tk.Button(canvas1, text="4. Live prediction", font=('Algerian', 15), bg="white", fg="red", command=prediction)
b4.place(x=5, y=200)

canvas2 = Canvas(window, width=500, height=250, bg="black")
canvas2.place(x=5, y=380)
def activate_paint(e):
    global lastx, lasty, points
    canvas2.bind('<B1-Motion>', paint)
    lastx, lasty = e.x, e.y
    points = [(lastx, lasty)]  # Initialize points list with the first point

def paint(e):
    global lastx, lasty, points
    x, y = e.x, e.y
    points.append((x, y))

    if len(points) > 2:  # Ensure enough points for smoother curves
        brush_size = brush_size_slider.get()  # Get the brush size from the slider
        canvas2.create_line(points[-2], points[-1], width=brush_size, fill="white", capstyle=tk.ROUND, smooth=True)
    lastx, lasty = x, y

# Adding a slider to control brush size
brush_size_slider = tk.Scale(window, from_=1, to=50, orient=tk.HORIZONTAL, label="Brush Size")
brush_size_slider.set(15)  # Default brush size
brush_size_slider.place(x=700, y=50)



canvas2.bind('<1>', activate_paint)

def clear():
    canvas2.delete("all")

btn = tk.Button(canvas2, text="clear", fg="white", bg="green", command=clear)
btn.place(x=0, y=0)

canvas3 = Canvas(window, width=400, height=530, bg="green")
canvas3.place(x=515, y=120)

window.geometry("800x680")
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\rajpu\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\rajpu\AppData\Local\Temp\ipykernel_26700\1682401480.py", line 126, in prediction
#     img_label = tk.Label(canvas3, image=photo, width=300, height=200)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rajpu\anaconda3\Lib\tkinter\__init__.py", line 3214, in __init__
#     Widget.__init__(self, master, 'label', cnf, kw)
#   File "C:\Users\rajpu\anaconda3\Lib\tkinter\__init__.py", line 2628, in __init__
#     self.tk.call(
# _tkinter.TclError: image "pyimage13" doesn't exist

# %%
# !pip install customtkinter
# Out:
# Requirement already satisfied: customtkinter in c:\users\rajpu\anaconda3\lib\site-packages (5.2.2)
# Requirement already satisfied: darkdetect in c:\users\rajpu\anaconda3\lib\site-packages (from customtkinter) (0.8.0)
# Requirement already satisfied: packaging in c:\users\rajpu\anaconda3\lib\site-packages (from customtkinter) (23.0)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 196
#     193     lastx, lasty = x, y
#     195 # Adding a slider to control brush size
# --> 196 brush_size_slider = ctk.CTkSlider(window, from_=1, to=50, orientation="horizontal", label="Brush Size")
#     197 brush_size_slider.set(15)  # Default brush size
#     198 brush_size_slider.place(x=700, y=50)
#
# File ~\anaconda3\Lib\site-packages\customtkinter\windows\widgets\ctk_slider.py:56, in CTkSlider.__init__(self, master, width, height, corner_radius, button_corner_radius, border_width, button_length, bg_color, fg_color, border_color, progress_color, button_color, button_hover_color, from_, to, state, number_of_steps, hover, command, variable, orientation, **kwargs)
#      53         height = 16
#      55 # transfer basic functionality (_bg_color, size, __appearance_mode, scaling) to CTkBaseClass
# ---> 56 super().__init__(master=master, bg_color=bg_color, width=width, height=height, **kwargs)
#      58 # color
#      59 self._border_color = self._check_color_type(border_color, transparency=True)
#
# File ~\anaconda3\Lib\site-packages\customtkinter\windows\widgets\core_widget_classes\ctk_base_class.py:46, in CTkBaseClass.__init__(self, master, width, height, bg_color, **kwargs)
#      43 CTkScalingBaseClass.__init__(self, scaling_type="widget")
#      45 # check if kwargs is empty, if not raise error for unsupported arguments
# ---> 46 check_kwargs_empty(kwargs, raise_error=True)
#      48 # dimensions independent of scaling
#      49 self._current_width = width  # _current_width and _current_height in pixel, represent current size of the widget
#
# File ~\anaconda3\Lib\site-packages\customtkinter\windows\widgets\utility\utility_functions.py:18, in check_kwargs_empty(kwargs_dict, raise_error)
#      16 if len(kwargs_dict) > 0:
#      17     if raise_error:
# ---> 18         raise ValueError(f"{list(kwargs_dict.keys())} are not supported arguments. Look at the documentation for supported arguments.")
#      19     else:
#      20         return True
#
# ValueError: ['label'] are not supported arguments. Look at the documentation for supported arguments.

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 217
#     214 canvas3 = Canvas(window, width=400, height=530, bg="green")
#     215 canvas3.place(x=515, y=120)
# --> 217 window.mainloop()
#
# File ~\anaconda3\Lib\site-packages\customtkinter\windows\ctk_tk.py:165, in CTk.mainloop(self, *args, **kwargs)
#     161             self.deiconify()
#     163     self._window_exists = True
# --> 165 super().mainloop(*args, **kwargs)
#
# File ~\anaconda3\Lib\tkinter\__init__.py:1485, in Misc.mainloop(self, n)
#    1483 def mainloop(self, n=0):
#    1484     """Call the mainloop of Tk."""
# -> 1485     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import tkinter as tk
from tkinter import Canvas, messagebox
import pyscreenshot as ImageGrab
import time
import os
from PIL import Image, ImageTk

window = tk.Tk()
window.title("Project")
window.resizable(True, True)

header = tk.Button(window, width=80, height=4, bg="pink", text="Handwritten Single Digit Recognition", font=("Arial", 14))
header.place(x=5, y=0)

canvas1 = Canvas(window, width=500, height=250, bg='ivory')
canvas1.place(x=5, y=120)

l1 = tk.Label(canvas1, text="Digit", font=('Algerian', 20))
l1.place(x=5, y=0)

t1 = tk.Entry(canvas1, width=20, border=5)
t1.place(x=150, y=5)

def screen_capture():
    os.startfile("C:/ProgramData/Microsoft/Windows/Start Menu/Programs/Accessories/Paint")
    s1 = t1.get()
    os.chdir("E:/DS and ML/Untitled Folder/Untitled Folder/captured_images")
    os.mkdir(s1)
    os.chdir("E:/DS and ML/Untitled Folder/Untitled Folder/")
    
    images_folder = "captured_images/" + s1 + "/"
    time.sleep(15)
    for i in range(0, 5):
        time.sleep(8)
        im = ImageGrab.grab(bbox=(60, 170, 400, 550))  # x1,y1,x2,y2
        print("saved......", i)
        im.save(images_folder + str(i) + '.png')
        print("clear screen now and redraw now........")
    messagebox.showinfo("Result", "Capturing screen is completed!!")

b1 = tk.Button(canvas1, text="1. Open paint and capture the screen", font=('Algerian', 15), bg="orange", fg="black", command=screen_capture)
b1.place(x=5, y=50)

def generate_dataset():
    import cv2
    import csv
    import glob

    header = ["label"]
    for i in range(0, 784):
        header.append("pixel" + str(i))
    with open('dataset.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow(header)

    for label in range(10):
        dirList = glob.glob("captured_images/" + str(label) + "/*.png")

        for img_path in dirList:
            im = cv2.imread(img_path)
            im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            im_gray = cv2.GaussianBlur(im_gray, (15, 15), 0)
            roi = cv2.resize(im_gray, (28, 28), interpolation=cv2.INTER_AREA)

            data = []
            data.append(label)
            rows, cols = roi.shape

            for i in range(rows):
                for j in range(cols):
                    k = roi[i, j]
                    if k > 100:
                        k = 1
                    else:
                        k = 0
                    data.append(k)
            with open('dataset.csv', 'a') as f:
                writer = csv.writer(f)
                writer.writerow(data)
    messagebox.showinfo("Result", "Generating dataset is completed!!")

b2 = tk.Button(canvas1, text="2. Generate dataset", font=('Algerian', 15), bg="pink", fg="blue", command=generate_dataset)
b2.place(x=5, y=100)

def train_save_accuracy():
    import pandas as pd
    from sklearn.utils import shuffle
    from sklearn.model_selection import train_test_split
    from sklearn.svm import SVC
    import joblib
    from sklearn import metrics

    data = pd.read_csv('dataset.csv')
    data = shuffle(data)
    X = data.drop(["label"], axis=1)
    Y = data["label"]

    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.2)

    classifier = SVC(kernel="linear", random_state=6)
    classifier.fit(train_x, train_y)
    joblib.dump(classifier, "model/digit_recognizer")

    prediction = classifier.predict(test_x)
    acc = metrics.accuracy_score(prediction, test_y)
    messagebox.showinfo("Result", f"Your accuracy is {acc}")

b3 = tk.Button(canvas1, text="3. Train the model and calculate accuracy", font=('Algerian', 15), bg="green", fg="white", command=train_save_accuracy)
b3.place(x=5, y=150)

def prediction():
    import joblib
    import cv2
    import numpy as np

    model = joblib.load("model/digit_recognizer")

    img = ImageGrab.grab(bbox=(400, 550, 930, 1080))
    img.save("paint.png")

    im = cv2.imread("paint.png")
    load = Image.open("paint.png")
    load = load.resize((280, 280))
    photo = ImageTk.PhotoImage(load)

    img_label = tk.Label(canvas3, image=photo, width=300, height=200)
    img_label.image = photo  # Keep reference to avoid garbage collection
    img_label.place(x=0, y=0)

    im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    im_gray = cv2.GaussianBlur(im_gray, (15, 15), 0)

    ret, im_th = cv2.threshold(im_gray, 100, 255, cv2.THRESH_BINARY)
    roi = cv2.resize(im_th, (28, 28), interpolation=cv2.INTER_AREA)

    rows, cols = roi.shape

    X = []
    for i in range(rows):
        for j in range(cols):
            k = roi[i, j]
            if k > 100:
                k = 1
            else:
                k = 0
            X.append(k)

    predictions = model.predict([X])

    a1 = tk.Label(canvas3, text="Prediction= ", font=("Algerian", 20))
    a1.place(x=5, y=350)

    b1 = tk.Label(canvas3, text=predictions[0], font=("Algerian", 20))
    b1.place(x=200, y=350)

b4 = tk.Button(canvas1, text="4. Live prediction", font=('Algerian', 15), bg="white", fg="red", command=prediction)
b4.place(x=5, y=200)

canvas2 = Canvas(window, width=500, height=250, bg="black")
canvas2.place(x=5, y=380)
def activate_paint(e):
    global lastx, lasty, points
    canvas2.bind('<B1-Motion>', paint)
    lastx, lasty = e.x, e.y
    points = [(lastx, lasty)]  # Initialize points list with the first point

def paint(e):
    global lastx, lasty, points
    x, y = e.x, e.y
    points.append((x, y))

    if len(points) > 2:  # Ensure enough points for smoother curves
        brush_size = brush_size_slider.get()  # Get the brush size from the slider
        canvas2.create_line(points[-2], points[-1], width=brush_size, fill="white", capstyle=tk.ROUND, smooth=True)
    lastx, lasty = x, y

# Adding a slider to control brush size
brush_size_slider = tk.Scale(window, from_=1, to=50, orient=tk.HORIZONTAL, label="Brush Size")
brush_size_slider.set(15)  # Default brush size
brush_size_slider.place(x=700, y=50)



canvas2.bind('<1>', activate_paint)

def clear():
    canvas2.delete("all")

btn = tk.Button(canvas2, text="clear", fg="white", bg="green", command=clear)
btn.place(x=0, y=0)

canvas3 = Canvas(window, width=400, height=530, bg="green")
canvas3.place(x=515, y=120)

window.geometry("800x680")
window.mainloop()
# Out:
# C:\Users\rajpu\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\rajpu\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\rajpu\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
